# %% [markdown]
# Let’s build a **Book Store App using FastAPI (Python)** step-by-step—clean, practical, and portfolio-ready.
#
# ---
#
# # 🔷 1. What You’ll Build
#
# A simple **Book Store API** with:
#
# ✅ Add books
# ✅ View books
# ✅ Update books
# ✅ Delete books
#
# 👉 This is called a **CRUD API**
#
# ---
#
# # 🔷 2. Tech Stack
#
# * Python
# * FastAPI
# * Uvicorn (server)
# * Pydantic (data validation)
#
# ---
#
# # 🔷 3. Install Requirements
#
# ```bash
# pip install fastapi uvicorn
# ```
#
# ---
#
# # 🔷 4. Basic FastAPI App
#
# Create file: `main.py`
#
# ```python
# from fastapi import FastAPI
#
# app = FastAPI()
#
# @app.get("/")
# def home():
#     return {"message": "Welcome to Book Store API"}
# ```
#
# ---
#
# ## ▶️ Run App
#
# ```bash
# uvicorn main:app --reload
# ```
#
# 👉 Open:
#
# * [http://127.0.0.1:8000](http://127.0.0.1:8000)
# * Docs: [http://127.0.0.1:8000/docs](http://127.0.0.1:8000/docs)
#
# ---
#
# # 🔷 5. Create Book Model
#
# Use Pydantic:
#
# ```python
# from pydantic import BaseModel
#
# class Book(BaseModel):
#     id: int
#     title: str
#     author: str
#     price: float
# ```
#
# ---
#
# # 🔷 6. Fake Database
#
# ```python
# books = []
# ```
#
# ---
#
# # 🔷 7. CRUD Operations
#
# ---
#
# ## 📌 1. Add Book (POST)
#
# ```python
# @app.post("/books/")
# def add_book(book: Book):
#     books.append(book)
#     return {"message": "Book added", "book": book}
# ```
#
# ---
#
# ## 📌 2. Get All Books (GET)
#
# ```python
# @app.get("/books/")
# def get_books():
#     return books
# ```
#
# ---
#
# ## 📌 3. Get Book by ID
#
# ```python
# @app.get("/books/{book_id}")
# def get_book(book_id: int):
#     for book in books:
#         if book.id == book_id:
#             return book
#     return {"error": "Book not found"}
# ```
#
# ---
#
# ## 📌 4. Update Book
#
# ```python
# @app.put("/books/{book_id}")
# def update_book(book_id: int, updated_book: Book):
#     for i, book in enumerate(books):
#         if book.id == book_id:
#             books[i] = updated_book
#             return {"message": "Book updated"}
#     return {"error": "Book not found"}
# ```
#
# ---
#
# ## 📌 5. Delete Book
#
# ```python
# @app.delete("/books/{book_id}")
# def delete_book(book_id: int):
#     for i, book in enumerate(books):
#         if book.id == book_id:
#             books.pop(i)
#             return {"message": "Book deleted"}
#     return {"error": "Book not found"}
# ```
#
# ---
#
# # 🔷 8. Full Code (Ready to Run)
#
# ```python
# from fastapi import FastAPI
# from pydantic import BaseModel
#
# app = FastAPI()
#
# class Book(BaseModel):
#     id: int
#     title: str
#     author: str
#     price: float
#
# books = []
#
# @app.get("/")
# def home():
#     return {"message": "Welcome to Book Store API"}
#
# @app.post("/books/")
# def add_book(book: Book):
#     books.append(book)
#     return {"message": "Book added", "book": book}
#
# @app.get("/books/")
# def get_books():
#     return books
#
# @app.get("/books/{book_id}")
# def get_book(book_id: int):
#     for book in books:
#         if book.id == book_id:
#             return book
#     return {"error": "Book not found"}
#
# @app.put("/books/{book_id}")
# def update_book(book_id: int, updated_book: Book):
#     for i, book in enumerate(books):
#         if book.id == book_id:
#             books[i] = updated_book
#             return {"message": "Book updated"}
#     return {"error": "Book not found"}
#
# @app.delete("/books/{book_id}")
# def delete_book(book_id: int):
#     for i, book in enumerate(books):
#         if book.id == book_id:
#             books.pop(i)
#             return {"message": "Book deleted"}
#     return {"error": "Book not found"}
# ```
#
# ---
#
# # 🔷 9. Test Using Swagger UI
#
# 👉 Go to:
#
# ```
# http://127.0.0.1:8000/docs
# ```
#
# You can:
#
# * Add book
# * Get book
# * Delete book
#
# ---
#
# # 🔷 10. Upgrade This Project (IMPORTANT 🚀)
#
# To make it **job-ready**, improve it:
#
# ---
#
# ## 🧠 1. Add Database (SQLite)
#
# Use:
#
# ```bash
# pip install sqlalchemy
# ```
#
# ---
#
# ## 🔐 2. Add Authentication
#
# * Login system
# * JWT tokens
#
# ---
#
# ## 📁 3. Proper Project Structure
#
# ```text
# app/
# ├── main.py
# ├── models.py
# ├── database.py
# ├── routes/
# ```
#
# ---
#
# ## 🌐 4. Deploy Online
#
# * Render
# * Railway
#
# ---
#
# # 🔷 11. Portfolio Value
#
# 👉 This project shows:
#
# * API development
# * Backend skills
# * Python expertise
#
# ---
#
# # 🔥 Final Insight
#
# 👉 FastAPI is one of the **fastest growing backend frameworks**
# 👉 Combine it with AI → VERY powerful
#
# ---
