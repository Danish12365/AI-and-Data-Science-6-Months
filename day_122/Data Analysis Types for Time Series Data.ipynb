# %% [markdown]
# Data analysis types in time series
# 1. Descriptive
# 2. Time series forcasting
# 3. Time series classification/ regression
# 4. Time series decomposition
# 5. Soectral analysis
#
# Types of data in time series
# 1. Time series data
# 2. Cross sectional data
# 3. Pooled data
