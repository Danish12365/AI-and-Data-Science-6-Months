# %% [markdown]
# Important terms in time series
# 1. Trend
# 2. Stationarity
# 3. Seasonality
# 4. Cyclic pattern
# 5. Auto correlation
# 6. lag
# 7. white noise
# 8. moving average
# 9. ARIMA
# 10. forecasting
# 11. outliers
