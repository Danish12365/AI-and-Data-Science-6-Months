# %% [markdown]
# 1. Tokenization
# 2. Stemming
# 3. Lemmatization
# 4. Stop words
# 5. BOW (bag of words)
# 6. TE-IDE: (TERM FREQUENCY,  INVERSE  DOCUMENT FREQUENCY)
# 7. NER (named entity recognition)
# 8.  Pos (parts of speech)
# 9. Syntax and passing
# 10. Semantic analysis
# 11. Sentiment analysis
# 12. Words Embedding
# 13. Sequence  to sequence models
# 14. Attention mechanism
# 15. Transforms
# 16. Language models
# 17. BERT (bidirectional encoder representation from transformers)
# 18. Gpt ( generative preordained Transformers)
